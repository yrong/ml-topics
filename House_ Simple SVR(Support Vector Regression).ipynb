# %% [markdown]
# ref: this notebook has been fork from https://www.kaggle.com/himaoka/house-simple-svr-support-vector-regression

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
# Suppress warnings
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=DeprecationWarning)
warnings.filterwarnings(action='ignore', category=FutureWarning)

# %% [markdown]
# * [Load Data and Libraries](#load)
# * [Check Data](#check-data)
# * [Data Pre-Processing](#pre-processing)
# * [Training and Prediction](#training-prediction)

# %% [markdown]
# # Load Data and Libraries <a id="load"></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, MinMaxScaler, StandardScaler

# Set pandas data display option
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
# Load csv data
train = pd.read_csv("./input/train.csv")
compe = pd.read_csv("./input/test.csv")
sample_sub = pd.read_csv("./input/sample_submission.csv")

# All data
data  = train.append(compe)

# %% [markdown]
# # Check Data <a id="check-data"></a>

# %% [markdown]
# There's 81 columns in data

# %%
# Columns
print(len(data.columns))
data.columns
# Out:
# 81
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr',
#        'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st',
#        'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation',
#        'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea',
#        'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'Id', 'KitchenAbvGr',
#        'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig',
#        'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold',
#        'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PavedDrive', 'PoolArea', 'PoolQC', 'RoofMatl', 'RoofStyle',
#        'SaleCondition', 'SalePrice', 'SaleType', 'ScreenPorch', 'Street',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %% [markdown]
# Check what types of data in each columns

# %%
# Data example
data.sample(n=20)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 340        832       629          0   NaN             4     1Fam       TA
# 785       1342         0          0   NaN             3     1Fam       TA
# 1285      1008         0          0   NaN             2     1Fam       TA
# 114       1436       884          0   NaN             3     1Fam       TA
# 502        483       504          0   NaN             2    Twnhs       TA
# 686        874       887          0   NaN             3     1Fam       TA
# 701       1164         0          0   NaN             3     1Fam       TA
# 1033      1654         0          0   NaN             3     1Fam       TA
# 1318      1084       867          0  Grvl             4   2fmCon       TA
# 1325       492         0          0   NaN             1     1Fam       TA
# 1085      1179         0          0   NaN             2     1Fam       TA
# 128        792       328          0   NaN             2     1Fam       TA
# 435        854       444          0  Grvl             3     1Fam       TA
# 627       1520         0          0   NaN             3     1Fam       TA
# 454       1728         0          0   NaN             4   Duplex       TA
# 45        1829         0          0   NaN             4     1Fam       TA
# 35        1132      1320          0   NaN             4     1Fam       TA
# 1181      1652         0        153   NaN             2   TwnhsE       TA
# 1181      1419         0          0   NaN             2   TwnhsE       TA
# 898       2364         0          0   NaN             2     1Fam       TA
#
#      BsmtExposure  BsmtFinSF1  BsmtFinSF2 BsmtFinType1 BsmtFinType2  \
# 340            No         0.0         0.0          Unf          Unf
# 785            No       251.0       630.0          Rec          LwQ
# 1285           No       658.0         0.0          GLQ          Unf
# 114            No       774.0       150.0          ALQ          LwQ
# 502            No       483.0         0.0          LwQ          Unf
# 686            No         0.0         0.0          Unf          Unf
# 701            No         0.0         0.0          Unf          Unf
# 1033           No       986.0         0.0          GLQ          Unf
# 1318           No         0.0         0.0          Unf          Unf
# 1325           No       416.0         0.0          LwQ          Unf
# 1085           No         0.0         0.0          Unf          Unf
# 128            No         0.0         0.0          Unf          Unf
# 435            No       626.0         0.0          Rec          Unf
# 627            Av       674.0       132.0          BLQ          LwQ
# 454            No      1606.0         0.0          ALQ          Unf
# 45             No       506.0         0.0          GLQ          Unf
# 35             Av         0.0         0.0          Unf          Unf
# 1181           Gd      1480.0         0.0          GLQ          Unf
# 1181           No       951.0         0.0          GLQ          Unf
# 898            Gd      2188.0         0.0          GLQ          Unf
#
#       BsmtFullBath  BsmtHalfBath BsmtQual  BsmtUnfSF CentralAir Condition1  \
# 340            0.0           0.0       TA      832.0          Y     Artery
# 785            0.0           0.0       TA      491.0          Y      Feedr
# 1285           1.0           0.0       TA      350.0          Y       Norm
# 114            1.0           0.0       TA      104.0          Y       Norm
# 502            0.0           0.0       TA        0.0          Y       Norm
# 686            0.0           0.0       Gd      874.0          Y       Norm
# 701            0.0           0.0       TA     1164.0          Y       Norm
# 1033           1.0           0.0       Gd      668.0          Y       Norm
# 1318           0.0           0.0       TA      938.0          N       Norm
# 1325           1.0           0.0       Fa       76.0          Y       Norm
# 1085           0.0           0.0       TA     1179.0          Y       Norm
# 128            0.0           0.0       TA      744.0          N       Norm
# 435            0.0           0.0       TA       94.0          Y       Norm
# 627            1.0           0.0       TA      350.0          Y       Norm
# 454            2.0           0.0       TA      122.0          Y       Norm
# 45             1.0           0.0       TA     1323.0          Y       Norm
# 35             0.0           0.0       Ex     1117.0          Y       Norm
# 1181           1.0           1.0       Ex      120.0          Y       Norm
# 1181           1.0           0.0       Gd      536.0          Y       Norm
# 898            1.0           0.0       Ex      142.0          Y       Norm
#
#      Condition2 Electrical  EnclosedPorch ExterCond ExterQual Exterior1st  \
# 340        Norm      FuseF              0        TA        TA     MetalSd
# 785        Norm      SBrkr              0        TA        TA     BrkFace
# 1285       Norm      FuseA              0        TA        TA     MetalSd
# 114        Norm      SBrkr              0        TA        TA     Wd Sdng
# 502        Norm      SBrkr              0        TA        TA     HdBoard
# 686        Norm      SBrkr              0        TA        Gd     VinylSd
# 701        Norm      SBrkr              0        TA        TA     HdBoard
# 1033       Norm      SBrkr              0        TA        Gd     VinylSd
# 1318       Norm      SBrkr             28        TA        Gd     MetalSd
# 1325       Norm      SBrkr             78        TA        TA     AsbShng
# 1085       Norm      SBrkr              0        TA        TA     HdBoard
# 128        Norm      FuseF              0        TA        TA     VinylSd
# 435        Norm      SBrkr              0        TA        TA     Wd Sdng
# 627        Norm      SBrkr            189        TA        TA     AsbShng
# 454        Norm      SBrkr              0        TA        TA     Plywood
# 45         Norm      SBrkr              0        TA        TA     HdBoard
# 35         Norm      SBrkr              0        TA        Gd     VinylSd
# 1181       Norm      SBrkr              0        TA        Ex     CemntBd
# 1181       Norm      SBrkr              0        TA        Gd     MetalSd
# 898        Norm      SBrkr              0        TA        Ex     VinylSd
#
#      Exterior2nd  Fence FireplaceQu  Fireplaces Foundation  FullBath  \
# 340      MetalSd    NaN         NaN           0     CBlock         2
# 785      Wd Sdng    NaN          Gd           1     CBlock         2
# 1285     MetalSd  MnPrv         NaN           0     CBlock         1
# 114      Wd Sdng  MnPrv          TA           1     CBlock         2
# 502      HdBoard    NaN         NaN           0     CBlock         1
# 686      VinylSd    NaN         NaN           0      PConc         3
# 701      HdBoard    NaN         NaN           0     CBlock         1
# 1033     VinylSd    NaN         NaN           0      PConc         2
# 1318     MetalSd    NaN         NaN           0      PConc         2
# 1325     AsbShng    NaN         NaN           0     BrkTil         1
# 1085     HdBoard  GdPrv         NaN           0     CBlock         1
# 128      VinylSd    NaN         NaN           0     CBlock         1
# 435      Wd Sdng    NaN          Gd           2     CBlock         1
# 627      AsbShng    NaN          Gd           2     CBlock         1
# 454      Plywood    NaN         NaN           0     CBlock         2
# 45       HdBoard    NaN         NaN           0     CBlock         2
# 35       VinylSd    NaN          Gd           1      PConc         3
# 1181     CmentBd    NaN          Gd           1      PConc         2
# 1181     MetalSd    NaN         NaN           0      PConc         2
# 898      VinylSd    NaN          Gd           2      PConc         2
#
#      Functional  GarageArea  GarageCars GarageCond GarageFinish GarageQual  \
# 340         Typ       384.0         1.0         TA          Unf         TA
# 785         Typ       457.0         2.0         TA          Unf         TA
# 1285        Typ       280.0         1.0         TA          RFn         TA
# 114         Typ       180.0         1.0         TA          Unf         TA
# 502         Typ       352.0         1.0         TA          Unf         TA
# 686         Typ       578.0         2.0         TA          Fin         TA
# 701         Typ       528.0         2.0         TA          Unf         TA
# 1033        Typ       900.0         3.0         TA          Unf         TA
# 1318        Typ       576.0         2.0         TA          Unf         TA
# 1325        Typ       200.0         1.0         TA          Unf         Fa
# 1085       Min2       622.0         2.0         TA          Fin         TA
# 128         Typ       480.0         2.0         Fa          Unf         TA
# 435         Typ       256.0         1.0         TA          Unf         TA
# 627         Typ       364.0         1.0         TA          RFn         TA
# 454         Typ       560.0         2.0         TA          Unf         TA
# 45          Typ       535.0         2.0         TA          RFn         TA
# 35          Typ       691.0         3.0         TA          Fin         TA
# 1181        Typ       482.0         2.0         TA          Fin         TA
# 1181        Typ       543.0         2.0         TA          Fin         TA
# 898         Typ       820.0         3.0         TA          Fin         TA
#
#      GarageType  GarageYrBlt  GrLivArea  HalfBath Heating HeatingQC  \
# 340      Detchd       1949.0       1461         0    GasA        TA
# 785      Attchd       1967.0       1342         0    GasA        TA
# 1285     Attchd       1952.0       1008         0    GasA        Ex
# 114      Detchd       1945.0       2320         1    GasA        Ex
# 502      Detchd       1975.0        987         1    GasA        Gd
# 686      Attchd       2007.0       1761         0    GasA        Ex
# 701      Attchd       1969.0       1164         1    GasA        TA
# 1033     Attchd       2002.0       1654         0    GasA        Ex
# 1318     Detchd       1993.0       1951         0    GasA        Gd
# 1325     Detchd       1921.0        492         0    GasA        TA
# 1085     Attchd       1960.0       1179         0    GasA        Gd
# 128      Detchd       1956.0       1120         0    GasA        Ex
# 435      Detchd       1940.0       1298         0    GasA        Ex
# 627     Basment       1955.0       1520         0    GasA        Ex
# 454      Detchd       1976.0       1728         0    GasA        TA
# 45       Attchd       1967.0       1829         0    GasA        Gd
# 35      BuiltIn       2004.0       2452         1    GasA        Ex
# 1181     Attchd       2008.0       1652         0    GasA        Ex
# 1181     Attchd       2002.0       1419         0    GasA        Ex
# 898      Attchd       2009.0       2364         1    GasA        Ex
#
#      HouseStyle    Id  KitchenAbvGr KitchenQual LandContour LandSlope  \
# 340      1.5Fin  1801             1          TA         Lvl       Gtl
# 785      1Story   786             1          TA         Lvl       Gtl
# 1285     1Story  2746             1          TA         Lvl       Gtl
# 114      2Story   115             1          Gd         Lvl       Mod
# 502      2Story  1963             1          TA         Lvl       Gtl
# 686      2Story   687             1          Gd         Lvl       Gtl
# 701      1Story   702             1          TA         Lvl       Gtl
# 1033     1Story  1034             1          Gd         Lvl       Gtl
# 1318     1.5Fin  2779             2          Fa         Lvl       Gtl
# 1325     1Story  2786             1          TA         Lvl       Gtl
# 1085     1Story  2546             1          TA         Lvl       Gtl
# 128      1.5Fin  1589             1          Fa         Lvl       Gtl
# 435      1.5Fin  1896             1          TA         Lvl       Gtl
# 627        SLvl   628             1          TA         Lvl       Gtl
# 454      1Story   455             2          TA         Lvl       Gtl
# 45       1Story  1506             1          TA         Lvl       Gtl
# 35       2Story    36             1          Gd         Lvl       Gtl
# 1181     1Story  1182             1          Gd         HLS       Mod
# 1181     1Story  2642             1          Gd         Lvl       Gtl
# 898      1Story   899             1          Ex         Lvl       Gtl
#
#       LotArea LotConfig  LotFrontage LotShape  LowQualFinSF  MSSubClass  \
# 340     10800    Inside         60.0      Reg             0          50
# 785      9790    Inside          NaN      Reg             0          20
# 1285    12778    Inside         66.0      Reg             0          20
# 114      7259    Inside         61.0      IR1             0          70
# 502      1890    Inside         21.0      Reg             0         160
# 686     10207    Inside         84.0      Reg             0          60
# 701      9600    Inside         80.0      Reg             0          20
# 1033     8125    Inside          NaN      Reg             0          20
# 1318     7745    Inside         56.0      Reg             0         190
# 1325     7830    Inside         52.0      Reg             0          30
# 1085     8240    Inside         80.0      Reg             0          20
# 128     11792    Inside         89.0      Reg             0          50
# 435      8212    Inside         45.0      Reg             0          50
# 627      9600    Inside         80.0      Reg             0          80
# 454      9297    Inside         63.0      Reg             0          90
# 45      10456    Inside          NaN      IR1             0          20
# 35      13418    Inside        108.0      Reg             0          60
# 1181     5587    Inside         64.0      IR1             0         120
# 1181     8773       FR2         26.0      IR2             0         120
# 898     12919    Inside        100.0      IR1             0          20
#
#      MSZoning  MasVnrArea MasVnrType MiscFeature  MiscVal  MoSold  \
# 340        RL         0.0       None         NaN        0       8
# 785        RL         0.0       None         NaN        0       9
# 1285       RL         0.0       None         NaN        0       1
# 114        RL         0.0       None         NaN        0       7
# 502        RM       422.0    BrkFace         NaN        0       4
# 686        FV         0.0       None         NaN        0       8
# 701        RL       168.0    BrkFace         NaN        0       7
# 1033       RL       295.0      Stone         NaN        0       2
# 1318       RM         0.0       None         NaN        0       4
# 1325       RM         0.0       None         NaN        0       6
# 1085       RL       198.0      Stone         NaN        0       6
# 128        RL         0.0       None         NaN        0       6
# 435        RL         0.0       None         NaN        0       9
# 627        RL       164.0    BrkFace         NaN        0       3
# 454        RL         0.0       None         NaN        0       7
# 45         RL       120.0    BrkFace         NaN        0       5
# 35         RL       132.0      Stone         NaN        0       9
# 1181       RM       186.0      Stone         NaN        0      11
# 1181       RH         0.0       None         NaN        0       9
# 898        RL       760.0      Stone         NaN        0       3
#
#      Neighborhood  OpenPorchSF  OverallCond  OverallQual PavedDrive  PoolArea  \
# 340         NAmes          204            7            4          Y         0
# 785        NWAmes            0            5            6          Y         0
# 1285        NAmes          154            6            5          Y         0
# 114       Crawfor            0            8            6          Y         0
# 502        BrDale            0            6            6          Y         0
# 686       Somerst          105            6            7          Y         0
# 701        NWAmes            0            5            7          Y         0
# 1033      CollgCr          136            5            7          Y         0
# 1318      OldTown            6            6            4          P         0
# 1325      OldTown            0            5            3          N         0
# 1085      Edwards            0            6            6          P         0
# 128       Edwards            0            5            4          P         0
# 435       Edwards            0            6            5          Y         0
# 627         NAmes            0            6            6          Y         0
# 454       Mitchel            0            5            5          Y         0
# 45         NWAmes           76            6            6          Y         0
# 35        NridgHt           32            5            8          Y         0
# 1181      Crawfor           53            5            8          Y         0
# 1181        NAmes           68            5            6          Y         0
# 898       NridgHt           67            5            9          Y         0
#
#      PoolQC RoofMatl RoofStyle SaleCondition  SalePrice SaleType  ScreenPorch  \
# 340     NaN  CompShg     Gable        Normal        NaN       WD            0
# 785     NaN  CompShg     Gable        Normal   161500.0       WD          197
# 1285    NaN  CompShg     Gable        Normal        NaN       WD            0
# 114     NaN  CompShg   Gambrel        Normal   259500.0       WD            0
# 502     NaN  CompShg     Gable        Normal        NaN       WD            0
# 686     NaN  CompShg     Gable       Partial   227875.0      New            0
# 701     NaN  CompShg       Hip        Normal   140000.0      COD            0
# 1033    NaN  CompShg     Gable        Normal   230000.0       WD            0
# 1318    NaN  CompShg     Gable        Normal        NaN       WD            0
# 1325    NaN  CompShg     Gable        Normal        NaN       WD            0
# 1085    NaN  CompShg       Hip        Normal        NaN       WD            0
# 128     NaN  CompShg     Gable       Abnorml        NaN       WD          160
# 435     NaN  CompShg     Gable        Normal        NaN       WD            0
# 627     NaN  CompShg     Gable        Normal   153000.0       WD            0
# 454     NaN  CompShg     Gable        Family   188000.0       WD            0
# 45      NaN  CompShg       Hip        Normal        NaN       WD            0
# 35      NaN  CompShg     Gable        Normal   309000.0       WD            0
# 1181    NaN  CompShg       Hip       Partial   392500.0      New            0
# 1181    NaN  CompShg     Gable        Normal        NaN       WD            0
# 898     NaN  CompShg       Hip       Partial   611657.0      New            0
#
#      Street  TotRmsAbvGrd  TotalBsmtSF Utilities  WoodDeckSF  YearBuilt  \
# 340    Pave             6        832.0    AllPub           0       1949
# 785    Pave             7       1372.0    AllPub           0       1967
# 1285   Pave             4       1008.0    AllPub           0       1952
# 114    Pave             9       1028.0    AllPub         224       1945
# 502    Pave             5        483.0    AllPub         411       1972
# 686    Pave             7        874.0    AllPub         144       2007
# 701    Pave             6       1164.0    AllPub           0       1969
# 1033   Pave             6       1654.0    AllPub           0       2002
# 1318   Pave             9        938.0    AllPub           0       1900
# 1325   Pave             3        492.0    AllPub           0       1921
# 1085   Pave             5       1179.0    AllPub           0       1960
# 128    Pave             5        744.0    AllPub           0       1948
# 435    Pave             6        720.0    AllPub          84       1941
# 627    Pave             7       1156.0    AllPub           0       1955
# 454    Pave             8       1728.0    AllPub           0       1976
# 45     Pave             8       1829.0    AllPub           0       1967
# 35     Pave             9       1117.0    AllPub         113       2004
# 1181   Pave             5       1600.0    AllPub         162       2008
# 1181   Pave             4       1487.0    AllPub         196       2002
# 898    Pave            11       2330.0    AllPub           0       2009
#
#       YearRemodAdd  YrSold
# 340           1996    2009
# 785           1967    2009
# 1285          2003    2006
# 114           2002    2007
# 502           1972    2008
# 686           2007    2007
# 701           1969    2006
# 1033          2002    2006
# 1318          1950    2006
# 1325          1950    2006
# 1085          1960    2007
# 128           1950    2010
# 435           1950    2009
# 627           1972    2010
# 454           1976    2006
# 45            1967    2010
# 35            2005    2006
# 1181          2008    2008
# 1181          2002    2006
# 898           2010    2010

# %% [markdown]
# Check types of each variables

# %%
types = pd.DataFrame(data.dtypes).rename(columns={0: 'type'}).sort_values(by=['type'],ascending=False)
types
# Out:
#                   type
# Heating         object
# FireplaceQu     object
# Foundation      object
# Functional      object
# GarageCond      object
# GarageFinish    object
# GarageQual      object
# GarageType      object
# Street          object
# HeatingQC       object
# HouseStyle      object
# SaleType        object
# KitchenQual     object
# LandContour     object
# LandSlope       object
# SaleCondition   object
# LotConfig       object
# LotShape        object
# RoofStyle       object
# RoofMatl        object
# MSZoning        object
# MasVnrType      object
# MiscFeature     object
# PoolQC          object
# Neighborhood    object
# Utilities       object
# PavedDrive      object
# Fence           object
# Electrical      object
# BsmtQual        object
# Exterior2nd     object
# CentralAir      object
# Condition1      object
# Condition2      object
# BsmtFinType2    object
# BsmtExposure    object
# BsmtCond        object
# ExterCond       object
# ExterQual       object
# BldgType        object
# Exterior1st     object
# Alley           object
# BsmtFinType1    object
# BsmtFinSF1     float64
# BsmtFinSF2     float64
# MasVnrArea     float64
# LotFrontage    float64
# SalePrice      float64
# BsmtFullBath   float64
# BsmtHalfBath   float64
# BsmtUnfSF      float64
# GarageYrBlt    float64
# GarageCars     float64
# TotalBsmtSF    float64
# GarageArea     float64
# ScreenPorch      int64
# TotRmsAbvGrd     int64
# WoodDeckSF       int64
# OverallQual      int64
# YearBuilt        int64
# PoolArea         int64
# YearRemodAdd     int64
# 1stFlrSF         int64
# OverallCond      int64
# OpenPorchSF      int64
# 3SsnPorch        int64
# BedroomAbvGr     int64
# EnclosedPorch    int64
# Fireplaces       int64
# FullBath         int64
# GrLivArea        int64
# HalfBath         int64
# 2ndFlrSF         int64
# Id               int64
# KitchenAbvGr     int64
# LotArea          int64
# LowQualFinSF     int64
# MSSubClass       int64
# MiscVal          int64
# MoSold           int64
# YrSold           int64

# %% [markdown]
# For data pre-processing, categorize variables into 'Numerical Variables', 'Categorical Variables(int)', 'Categorical Variables(string)'
#
# **Numerical Variables: **float and int variables
# ['MSSubClass', 'LotFrontage', 'LotArea', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'YrSold']
#
# **Categorical Variables(int): **some of int variables
# ['OverallQual', 'OverallCond', 'MoSold']
#
# **Categorical Variables(string): **string variables
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# Check how many data is missing

# %%
# Check missing values
def check_missing(df):
    null_val = df.isnull().sum()
    percent = 100 * df.isnull().sum()/len(df)
    missing_table = pd.concat([null_val, percent], axis=1)
    col = missing_table.rename(columns = {0 : 'Num', 1 : 'Rate'})
    return col

# Display columns missing values are under 1%.
print("Data #"+str(len(data)))
cols = check_missing(data)
types.join(cols).sort_values(by="Rate", ascending=False)
# Out:
# Data #2919
#                   type   Num       Rate
# PoolQC          object  2909  99.657417
# MiscFeature     object  2814  96.402878
# Alley           object  2721  93.216855
# Fence           object  2348  80.438506
# SalePrice      float64  1459  49.982871
# FireplaceQu     object  1420  48.646797
# LotFrontage    float64   486  16.649538
# GarageCond      object   159   5.447071
# GarageFinish    object   159   5.447071
# GarageQual      object   159   5.447071
# GarageYrBlt    float64   159   5.447071
# GarageType      object   157   5.378554
# BsmtCond        object    82   2.809181
# BsmtExposure    object    82   2.809181
# BsmtQual        object    81   2.774923
# BsmtFinType2    object    80   2.740665
# BsmtFinType1    object    79   2.706406
# MasVnrType      object    24   0.822199
# MasVnrArea     float64    23   0.787941
# MSZoning        object     4   0.137033
# BsmtFullBath   float64     2   0.068517
# Utilities       object     2   0.068517
# Functional      object     2   0.068517
# BsmtHalfBath   float64     2   0.068517
# GarageCars     float64     1   0.034258
# BsmtUnfSF      float64     1   0.034258
# TotalBsmtSF    float64     1   0.034258
# BsmtFinSF1     float64     1   0.034258
# GarageArea     float64     1   0.034258
# BsmtFinSF2     float64     1   0.034258
# Exterior1st     object     1   0.034258
# Electrical      object     1   0.034258
# Exterior2nd     object     1   0.034258
# SaleType        object     1   0.034258
# KitchenQual     object     1   0.034258
# 3SsnPorch        int64     0   0.000000
# 2ndFlrSF         int64     0   0.000000
# PoolArea         int64     0   0.000000
# MoSold           int64     0   0.000000
# MiscVal          int64     0   0.000000
# MSSubClass       int64     0   0.000000
# LowQualFinSF     int64     0   0.000000
# LotArea          int64     0   0.000000
# KitchenAbvGr     int64     0   0.000000
# Id               int64     0   0.000000
# HalfBath         int64     0   0.000000
# OpenPorchSF      int64     0   0.000000
# GrLivArea        int64     0   0.000000
# FullBath         int64     0   0.000000
# Fireplaces       int64     0   0.000000
# EnclosedPorch    int64     0   0.000000
# YearRemodAdd     int64     0   0.000000
# 1stFlrSF         int64     0   0.000000
# OverallCond      int64     0   0.000000
# OverallQual      int64     0   0.000000
# BedroomAbvGr     int64     0   0.000000
# YearBuilt        int64     0   0.000000
# Heating         object     0   0.000000
# WoodDeckSF       int64     0   0.000000
# RoofStyle       object     0   0.000000
# Foundation      object     0   0.000000
# Street          object     0   0.000000
# HeatingQC       object     0   0.000000
# HouseStyle      object     0   0.000000
# LandContour     object     0   0.000000
# LandSlope       object     0   0.000000
# SaleCondition   object     0   0.000000
# LotConfig       object     0   0.000000
# LotShape        object     0   0.000000
# RoofMatl        object     0   0.000000
# TotRmsAbvGrd     int64     0   0.000000
# Neighborhood    object     0   0.000000
# PavedDrive      object     0   0.000000
# CentralAir      object     0   0.000000
# Condition1      object     0   0.000000
# Condition2      object     0   0.000000
# ExterCond       object     0   0.000000
# ExterQual       object     0   0.000000
# BldgType        object     0   0.000000
# ScreenPorch      int64     0   0.000000
# YrSold           int64     0   0.000000

# %% [markdown]
# # Data Pre-Processing <a id="pre-processing"></a>

# %% [markdown]
# Drop variables more than 40% data was missing..

# %%
# Drop more than 40% missing variables
data.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=1, inplace = True)

# %% [markdown]
# Process categorical variables(string)
# 1. Fill missing data by most frequent value
# 2. One-Hot Encoding

# %%
# Fill missing data and replace with dummy value
categorical_variables_string = \
    ['MSZoning', 'Street', 'LotShape', 'LandContour', 
     'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 
     'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 
     'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 
     'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 
     'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 
     'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 
     'Electrical', 'KitchenQual', 'Functional', 'GarageType', 
     'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 
     'SaleType', 'SaleCondition']

for v in categorical_variables_string:
    # Fill NaN with mode
    data[v] = data[v].fillna(data[v].mode()[0])
    # One-Hot Encoding
    data = pd.get_dummies(data, columns=[v], drop_first=True)
    # Categorize
    # data[v] = pd.factorize(data[v])[0]

# %% [markdown]
# Process categorical variables(int)
# 1. Do nothing, because there's no missing data

# %%
# There's no missing data
categorical_variables_int = \
    ['OverallQual', 'OverallCond', 'MoSold']

# %% [markdown]
# Process numerical variables
# 1. Just fill missing data with average
# 2. Standardize values

# %%
# Fill missing data
numerical_variavles = \
    ['MSSubClass', 'LotFrontage', 'LotArea', 'YearBuilt', 
     'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 
     'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 
     'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 
     'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 
     'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 
     'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', 
     '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'YrSold']

ss = StandardScaler()
for v in numerical_variavles:
    # Fill NaN with mean
    data[v] = data[v].fillna(data[v].mean())
    # Standardize values
    data[v] = ss.fit_transform(data[[v]])

# %% [markdown]
# Data after processing is like this

# %%
# Data example
data.sample(n=10)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# 553  -0.697388  1.067397  -0.103331      0.169927    0.352564   -0.293130
# 76   -0.529147 -0.785025  -0.103331     -1.045801   -0.468594   -0.293130
# 144   1.448957 -0.785025  -0.103331      3.817112    1.955357   -0.293130
# 471  -1.365253  0.761771  -0.103331      0.169927   -0.244642   -0.293130
# 374  -0.462870  1.282035  -0.103331      3.817112   -0.598135   -0.293130
# 351  -0.914062  0.722109  -0.103331      0.169927   -0.969192   -0.293130
# 1370 -0.814647  0.460810  -0.103331     -1.045801   -0.277576    0.327629
# 610  -1.242896 -0.785025  -0.103331     -1.045801   -0.969192   -0.293130
# 520  -1.186816  0.614790  -0.103331      0.169927   -0.969192   -0.293130
# 1255 -1.604869  0.498139  -0.103331     -1.045801   -0.969192   -0.293130
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  Fireplaces  \
# 553      -0.819679      3.822419  -0.629896      -0.359601   -0.924311
# 76       -0.819679     -0.249895   0.371485      -0.359601   -0.924311
# 144       1.087023     -0.249895  -0.374999      -0.359601   -0.924311
# 471      -0.819679     -0.249895  -0.607138      -0.359601   -0.924311
# 374      -0.819679     -0.249895   0.660520       1.228362   -0.924311
# 351      -0.819679     -0.249895   0.546727       3.439056   -0.924311
# 1370     -0.819679     -0.249895  -0.320379       2.722915   -0.924311
# 610      -0.819679     -0.249895   0.253140      -0.359601   -0.924311
# 520      -0.819679     -0.249895  -1.276243       2.909735   -0.924311
# 1255     -0.819679     -0.249895  -0.070033      -0.359601   -0.924311
#
#       FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  HalfBath  \
# 553   0.781366    0.005227    0.306528     0.598733   0.354255  1.232599
# 76   -1.027363   -0.881821   -1.006906    -0.889392  -1.084582 -0.756321
# 144   0.781366    0.144554    0.306528    -0.607855   0.449123 -0.756321
# 471  -1.027363   -0.152677    0.306528     0.920490  -0.422480  1.232599
# 374   0.781366   -2.196138   -2.320339     0.000000   0.717916  1.232599
# 351  -1.027363   -2.196138   -2.320339     0.000000  -0.106252 -0.756321
# 1370 -1.027363   -0.626388   -1.006906    -0.446977  -0.250531 -0.756321
# 610  -1.027363   -0.765715   -1.006906     0.759611  -1.637981 -0.756321
# 520   0.781366   -2.196138   -2.320339     0.000000  -0.408645 -0.756321
# 1255  0.781366    0.107400    0.306528     1.000929  -0.831600  1.232599
#
#         Id  KitchenAbvGr   LotArea  LotFrontage  LowQualFinSF  MSSubClass  \
# 553   2014     -0.207698 -0.214074    -0.906006     -0.101197    0.067331
# 76      77     -0.207698 -0.214708     0.000000     -0.101197   -0.873616
# 144    145      4.455931 -0.135450     0.032578     -0.101197    0.773042
# 471   1932     -0.207698  0.033084    -0.342855     -0.101197    0.067331
# 374   1835     -0.207698 -0.547338    -1.328368     -0.101197    3.125411
# 351   1812     -0.207698 -0.004326    -0.624430     -0.101197   -0.167905
# 1370  1371     -0.207698 -0.604657     0.971162     -0.101197   -0.167905
# 610   2071     -0.207698 -0.604657    -0.436714     -0.101197   -0.638379
# 520    521      4.455931  0.080131    -0.436714     -0.101197    3.125411
# 1255  2716     -0.207698 -0.725510     0.000000     -0.101197    2.419700
#
#       MasVnrArea   MiscVal  MoSold  OpenPorchSF  OverallCond  OverallQual  \
# 553     0.099659 -0.089592      10     0.718034            5            6
# 76     -0.572250 -0.089592       4    -0.702843            7            4
# 144     1.309096 -0.089592      11    -0.702843            5            5
# 471    -0.572250 -0.089592       7    -0.702843            5            5
# 374     0.480408 -0.089592       5     2.079708            5            7
# 351    -0.572250 -0.089592       7    -0.702843            5            5
# 1370   -0.572250 -0.089592      10    -0.702843            6            4
# 610    -0.572250 -0.089592       7     0.895644            7            4
# 520    -0.572250 -0.089592       8     0.984448            7            4
# 1255   -0.572250 -0.089592       7     0.037197            5            7
#
#       PoolArea  SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# 553   -0.06315        NaN    -0.285935      0.349546    -0.376241    0.397535
# 76    -0.06315   135750.0    -0.285935     -1.562366    -0.226451   -0.740760
# 144   -0.06315   125000.0    -0.285935      2.261457     1.534723   -0.740760
# 471   -0.06315        NaN    -0.285935     -0.287758    -0.970864    0.444964
# 374   -0.06315        NaN    -0.285935      1.624153    -0.072121   -0.740760
# 351   -0.06315        NaN    -0.285935     -0.287758    -0.569153   -0.108374
# 1370  -0.06315   105000.0    -0.285935     -0.287758    -0.480641   -0.740760
# 610   -0.06315        NaN    -0.285935     -1.562366    -0.861926   -0.045135
# 520   -0.06315   106250.0    -0.285935      0.349546    -2.387066    0.998302
# 1255  -0.06315        NaN    -0.285935     -1.562366    -1.184202   -0.740760
#
#       YearBuilt  YearRemodAdd    YrSold  MSZoning_FV  MSZoning_RH  \
# 553    0.716075      0.466021  0.157646            0            0
# 76    -0.505602     -1.352965  0.157646            0            0
# 144   -0.274474     -1.017889 -1.363569            0            0
# 471    0.683057      0.370284  0.918253            0            0
# 374   -2.288589      0.753229  0.918253            0            0
# 351   -2.024443     -1.640173  0.918253            0            0
# 1370  -1.694260     -1.640173  0.918253            0            0
# 610   -1.033894      0.992569  0.157646            0            0
# 520   -2.354625      0.753229  0.157646            0            0
# 1255   1.046258      0.896833 -1.363569            1            0
#
#       MSZoning_RL  MSZoning_RM  Street_Pave  LotShape_IR2  LotShape_IR3  \
# 553             1            0            1             0             0
# 76              1            0            1             0             0
# 144             0            1            1             0             0
# 471             1            0            1             0             0
# 374             0            1            1             0             1
# 351             0            1            1             0             0
# 1370            1            0            1             0             0
# 610             1            0            1             0             0
# 520             1            0            1             0             0
# 1255            0            0            1             0             0
#
#       LotShape_Reg  LandContour_HLS  LandContour_Low  LandContour_Lvl  \
# 553              0                0                0                1
# 76               0                0                0                1
# 144              1                0                0                1
# 471              1                0                0                1
# 374              0                0                0                0
# 351              1                0                0                1
# 1370             1                0                0                1
# 610              1                0                0                1
# 520              1                0                0                1
# 1255             0                0                0                1
#
#       Utilities_NoSeWa          ...            Heating_OthW  Heating_Wall  \
# 553                  0          ...                       0             0
# 76                   0          ...                       0             0
# 144                  0          ...                       0             0
# 471                  0          ...                       0             0
# 374                  0          ...                       0             0
# 351                  0          ...                       0             0
# 1370                 0          ...                       0             0
# 610                  0          ...                       0             0
# 520                  0          ...                       0             0
# 1255                 0          ...                       0             0
#
#       HeatingQC_Fa  HeatingQC_Gd  HeatingQC_Po  HeatingQC_TA  CentralAir_Y  \
# 553              0             0             0             0             1
# 76               0             0             0             0             1
# 144              0             0             0             1             1
# 471              0             0             0             1             1
# 374              0             0             0             1             0
# 351              0             1             0             0             0
# 1370             0             0             0             0             1
# 610              0             1             0             0             1
# 520              0             0             0             1             0
# 1255             0             0             0             0             1
#
#       Electrical_FuseF  Electrical_FuseP  Electrical_Mix  Electrical_SBrkr  \
# 553                  0                 0               0                 1
# 76                   0                 0               0                 0
# 144                  0                 0               0                 1
# 471                  0                 0               0                 1
# 374                  1                 0               0                 0
# 351                  0                 0               0                 1
# 1370                 0                 0               0                 1
# 610                  0                 0               0                 1
# 520                  0                 0               0                 0
# 1255                 0                 0               0                 1
#
#       KitchenQual_Fa  KitchenQual_Gd  KitchenQual_TA  Functional_Maj2  \
# 553                0               1               0                0
# 76                 0               0               1                0
# 144                0               0               1                0
# 471                0               0               1                0
# 374                0               0               1                0
# 351                0               0               1                0
# 1370               0               0               1                0
# 610                0               0               1                0
# 520                0               0               1                0
# 1255               0               1               0                0
#
#       Functional_Min1  Functional_Min2  Functional_Mod  Functional_Sev  \
# 553                 0                0               0               0
# 76                  0                0               0               0
# 144                 0                0               0               0
# 471                 0                0               0               0
# 374                 0                0               0               0
# 351                 0                0               0               0
# 1370                0                0               0               0
# 610                 0                0               0               0
# 520                 0                0               0               0
# 1255                0                0               0               0
#
#       Functional_Typ  GarageType_Attchd  GarageType_Basment  \
# 553                1                  1                   0
# 76                 1                  0                   0
# 144                1                  0                   0
# 471                1                  0                   0
# 374                1                  1                   0
# 351                1                  1                   0
# 1370               1                  0                   0
# 610                1                  0                   0
# 520                1                  1                   0
# 1255               1                  1                   0
#
#       GarageType_BuiltIn  GarageType_CarPort  GarageType_Detchd  \
# 553                    0                   0                  0
# 76                     0                   0                  1
# 144                    0                   0                  1
# 471                    0                   0                  1
# 374                    0                   0                  0
# 351                    0                   0                  0
# 1370                   0                   0                  1
# 610                    0                   0                  1
# 520                    0                   0                  0
# 1255                   0                   0                  0
#
#       GarageFinish_RFn  GarageFinish_Unf  GarageQual_Fa  GarageQual_Gd  \
# 553                  1                 0              0              0
# 76                   0                 1              0              0
# 144                  0                 1              0              0
# 471                  0                 1              0              0
# 374                  0                 1              0              0
# 351                  0                 1              0              0
# 1370                 0                 0              0              0
# 610                  0                 1              0              0
# 520                  0                 1              0              0
# 1255                 1                 0              0              0
#
#       GarageQual_Po  GarageQual_TA  GarageCond_Fa  GarageCond_Gd  \
# 553               0              1              0              0
# 76                0              1              0              0
# 144               0              1              0              0
# 471               0              1              0              0
# 374               0              1              0              0
# 351               0              1              0              0
# 1370              0              1              0              0
# 610               0              1              0              0
# 520               0              1              0              0
# 1255              0              1              0              0
#
#       GarageCond_Po  GarageCond_TA  PavedDrive_P  PavedDrive_Y  SaleType_CWD  \
# 553               0              1             0             1             0
# 76                0              1             0             1             0
# 144               0              1             0             1             0
# 471               0              1             0             1             0
# 374               0              1             0             0             0
# 351               0              1             0             0             0
# 1370              0              1             0             1             0
# 610               0              1             0             0             0
# 520               0              1             0             0             0
# 1255              0              1             0             1             0
#
#       SaleType_Con  SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  \
# 553              0               0               0               0
# 76               0               0               0               0
# 144              0               0               1               0
# 471              0               0               0               0
# 374              0               0               0               0
# 351              0               0               0               0
# 1370             0               0               0               0
# 610              0               0               0               0
# 520              0               0               0               0
# 1255             0               0               0               0
#
#       SaleType_New  SaleType_Oth  SaleType_WD  SaleCondition_AdjLand  \
# 553              0             0            1                      0
# 76               0             0            1                      0
# 144              0             0            0                      0
# 471              0             0            1                      0
# 374              0             0            1                      0
# 351              0             0            1                      0
# 1370             0             0            1                      0
# 610              0             0            1                      0
# 520              0             0            1                      0
# 1255             0             0            1                      0
#
#       SaleCondition_Alloca  SaleCondition_Family  SaleCondition_Normal  \
# 553                      0                     0                     1
# 76                       0                     0                     1
# 144                      0                     0                     0
# 471                      0                     0                     1
# 374                      0                     0                     1
# 351                      0                     0                     1
# 1370                     0                     0                     1
# 610                      0                     0                     1
# 520                      0                     0                     1
# 1255                     0                     0                     1
#
#       SaleCondition_Partial
# 553                       0
# 76                        0
# 144                       0
# 471                       0
# 374                       0
# 351                       0
# 1370                      0
# 610                       0
# 520                       0
# 1255                      0
#
# [10 rows x 234 columns]

# %%
# Set data
train = data[:1460]
test  = data[1460:]

# %% [markdown]
# # Training and Prediction <a id="training-prediction"></a>

# %% [markdown]
# To select parameters for training, use feature selection library

# %%
possible_features = train.columns.copy().drop('SalePrice').drop('Id')

# Check feature importances
selector = SelectKBest(f_regression, len(possible_features))
selector.fit(train[possible_features], train['SalePrice'])
scores = -np.log10(selector.pvalues_)
indices = np.argsort(scores)[::-1]
print('Feature importances:')
for i in range(len(scores)):
    print('%.2f %s' % (scores[indices[i]], possible_features[indices[i]]))
# Out:
# Feature importances:
# 312.66 OverallQual
# 222.35 GrLivArea
# 168.60 GarageCars
# 157.28 GarageArea
# 151.02 TotalBsmtSF
# 146.27 1stFlrSF
# 136.37 ExterQual_TA
# 120.91 FullBath
# 107.56 TotRmsAbvGrd
# 102.52 YearBuilt
# 100.89 KitchenQual_TA
# 98.48 GarageFinish_Unf
# 95.50 YearRemodAdd
# 91.85 BsmtQual_TA
# 91.51 Foundation_PConc
# 82.39 MasVnrArea
# 80.79 GarageYrBlt
# 79.21 Fireplaces
# 73.86 ExterQual_Gd
# 67.59 BsmtFinType1_GLQ
# 57.14 Neighborhood_NridgHt
# 52.47 BsmtFinSF1
# 47.17 MasVnrType_None
# 44.53 SaleType_New
# 43.66 GarageType_Detchd
# 43.12 SaleCondition_Partial
# 40.91 Foundation_CBlock
# 38.85 LotFrontage
# 37.82 MasVnrType_Stone
# 37.80 Neighborhood_NoRidge
# 36.40 WoodDeckSF
# 35.76 KitchenQual_Gd
# 35.39 BsmtExposure_No
# 35.24 2ndFlrSF
# 34.46 OpenPorchSF
# 33.75 HeatingQC_TA
# 32.58 BsmtExposure_Gd
# 32.38 Exterior2nd_VinylSd
# 32.08 Exterior1st_VinylSd
# 28.57 MSZoning_RM
# 27.78 HalfBath
# 24.65 LotShape_Reg
# 23.95 LotArea
# 21.74 CentralAir_Y
# 20.68 MSZoning_RL
# 20.32 HouseStyle_2Story
# 20.27 SaleType_WD
# 20.23 Electrical_SBrkr
# 19.18 RoofStyle_Hip
# 19.11 GarageType_BuiltIn
# 19.01 BsmtQual_Gd
# 18.60 GarageType_Attchd
# 18.56 PavedDrive_Y
# 17.81 BsmtFullBath
# 17.45 RoofStyle_Gable
# 16.05 Neighborhood_StoneBr
# 15.93 BsmtUnfSF
# 13.67 MasVnrType_BrkFace
# 12.89 Neighborhood_OldTown
# 12.42 Neighborhood_NAmes
# 11.37 Neighborhood_Edwards
# 10.18 GarageFinish_RFn
# 10.13 RoofMatl_WdShngl
# 10.00 BedroomAbvGr
# 9.88 Exterior1st_MetalSd
# 9.54 Neighborhood_IDOTRR
# 9.36 Exterior2nd_MetalSd
# 9.30 Exterior2nd_Wd Sdng
# 8.96 Exterior1st_Wd Sdng
# 8.81 KitchenQual_Fa
# 8.48 SaleCondition_Normal
# 7.45 Neighborhood_BrkSide
# 7.28 LotConfig_CulDSac
# 7.11 Neighborhood_Somerst
# 6.91 ExterCond_Fa
# 6.74 GarageCond_TA
# 6.73 KitchenAbvGr
# 6.71 BsmtFinType1_Rec
# 6.62 HeatingQC_Gd
# 6.54 HeatingQC_Fa
# 6.51 Exterior1st_CemntBd
# 6.48 GarageQual_Fa
# 6.47 BsmtFinType1_Unf
# 6.46 BsmtFinType1_BLQ
# 6.27 GarageCond_Fa
# 6.10 BsmtQual_Fa
# 6.08 EnclosedPorch
# 6.07 Neighborhood_Sawyer
# 6.05 Exterior2nd_CmentBd
# 5.91 Electrical_FuseF
# 5.88 Neighborhood_Timber
# 5.87 LotShape_IR2
# 5.37 LandContour_HLS
# 5.35 Foundation_Slab
# 5.16 Condition1_Feedr
# 5.09 Functional_Typ
# 4.99 ExterQual_Fa
# 4.95 BldgType_Duplex
# 4.82 Condition1_Norm
# 4.79 Neighborhood_MeadowV
# 4.71 ScreenPorch
# 4.25 ExterCond_TA
# 4.20 RoofMatl_CompShg
# 3.98 Neighborhood_BrDale
# 3.80 BldgType_Twnhs
# 3.71 BldgType_2fmCon
# 3.57 GarageQual_TA
# 3.57 Exterior1st_HdBoard
# 3.43 HouseStyle_SFoyer
# 3.40 Heating_GasA
# 3.39 PoolArea
# 3.39 Heating_Grav
# 3.24 MSZoning_FV
# 3.17 BsmtCond_Gd
# 3.16 PavedDrive_P
# 3.10 HouseStyle_1.5Unf
# 2.91 BsmtFinType1_LwQ
# 2.90 MSSubClass
# 2.68 LotConfig_Inside
# 2.54 OverallCond
# 2.35 Exterior2nd_ImStucc
# 2.26 Neighborhood_CollgCr
# 2.19 Functional_Min2
# 2.19 Neighborhood_Crawfor
# 2.15 GarageType_CarPort
# 2.14 Functional_Maj2
# 2.02 Exterior2nd_HdBoard
# 1.91 MSZoning_RH
# 1.84 Functional_Min1
# 1.83 Neighborhood_SWISU
# 1.82 Neighborhood_Veenker
# 1.81 GarageCond_Po
# 1.74 HouseStyle_1Story
# 1.60 Heating_Wall
# 1.57 Neighborhood_Mitchel
# 1.54 BsmtFinType2_BLQ
# 1.49 BsmtFinType2_Unf
# 1.48 Neighborhood_ClearCr
# 1.43 BsmtCond_Po
# 1.37 Exterior2nd_Plywood
# 1.30 Exterior1st_WdShing
# 1.30 Exterior1st_BrkComm
# 1.28 SaleCondition_AdjLand
# 1.27 ExterCond_Gd
# 1.23 Condition1_PosN
# 1.19 Condition2_PosN
# 1.19 Condition2_Feedr
# 1.17 Electrical_FuseP
# 1.16 Condition2_PosA
# 1.15 Exterior2nd_Brk Cmn
# 1.13 Condition1_RRAe
# 1.12 SaleCondition_Family
# 1.12 MoSold
# 1.11 GarageQual_Po
# 1.09 LandContour_Low
# 1.09 Exterior2nd_Other
# 1.05 RoofMatl_WdShake
# 1.05 3SsnPorch
# 1.01 BsmtExposure_Mn
# 1.01 GarageQual_Gd
# 1.00 LandSlope_Mod
# 0.98 Exterior2nd_Stucco
# 0.96 Condition1_PosA
# 0.96 SaleType_ConLD
# 0.94 SaleType_Con
# 0.93 Street_Pave
# 0.91 Exterior2nd_Wd Shng
# 0.88 BsmtFinType2_Rec
# 0.87 Condition2_RRNn
# 0.85 HouseStyle_SLvl
# 0.83 Neighborhood_NPkVill
# 0.82 BsmtFinType2_LwQ
# 0.82 Electrical_Mix
# 0.79 LotShape_IR3
# 0.79 HouseStyle_2.5Fin
# 0.78 Exterior1st_Stone
# 0.77 Neighborhood_Gilbert
# 0.75 RoofStyle_Gambrel
# 0.74 SaleType_Oth
# 0.72 ExterCond_Po
# 0.66 Exterior1st_BrkFace
# 0.63 HeatingQC_Po
# 0.62 Condition2_Norm
# 0.59 Exterior1st_Stucco
# 0.58 GarageType_Basment
# 0.57 YrSold
# 0.55 LandSlope_Sev
# 0.53 LandContour_Lvl
# 0.53 SaleType_ConLw
# 0.51 Exterior1st_ImStucc
# 0.51 Exterior1st_AsphShn
# 0.49 HouseStyle_2.5Unf
# 0.49 Heating_OthW
# 0.48 LowQualFinSF
# 0.47 Exterior1st_CBlock
# 0.47 Exterior2nd_CBlock
# 0.47 BsmtCond_TA
# 0.46 Exterior2nd_BrkFace
# 0.46 Exterior2nd_AsphShn
# 0.43 Neighborhood_NWAmes
# 0.43 Condition1_RRNn
# 0.38 MiscVal
# 0.36 RoofStyle_Shed
# 0.36 Neighborhood_Blueste
# 0.35 Heating_GasW
# 0.35 RoofMatl_Membran
# 0.34 SaleType_CWD
# 0.31 LotConfig_FR3
# 0.30 Exterior1st_Plywood
# 0.29 Functional_Sev
# 0.28 BsmtHalfBath
# 0.28 Exterior2nd_Stone
# 0.27 Functional_Mod
# 0.26 SaleCondition_Alloca
# 0.24 Neighborhood_SawyerW
# 0.24 Condition2_RRAn
# 0.24 RoofMatl_Roll
# 0.23 SaleType_ConLI
# 0.23 Utilities_NoSeWa
# 0.19 Foundation_Stone
# 0.18 BsmtFinSF2
# 0.10 LotConfig_FR2
# 0.09 Condition1_RRAn
# 0.07 RoofMatl_Tar&Grv
# 0.06 Condition1_RRNe
# 0.05 BldgType_TwnhsE
# 0.04 Condition2_RRAe
# 0.04 Foundation_Wood
# 0.01 GarageCond_Gd
# 0.00 RoofStyle_Mansard
# 0.00 RoofMatl_Metal
# 0.00 BsmtFinType2_GLQ

# %% [markdown]
# This time, pick variables by their importances
#
# **Possible features(Ordered by importances)**
#     ['OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF',
#      '1stFlrSF', 'ExterQual_TA', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#      'KitchenQual_TA', 'GarageFinish_Unf', 'YearRemodAdd', 'BsmtQual_TA',
#      'Foundation_PConc', 'MasVnrArea', 'GarageYrBlt', 'Fireplaces',
#      'ExterQual_Gd', 'BsmtFinType1_GLQ', 'Neighborhood_NridgHt', 'BsmtFinSF1',
#      'MasVnrType_None', 'SaleType_New', 'GarageType_Detchd', 'SaleCondition_Partial',
#      'Foundation_CBlock', 'LotFrontage', 'MasVnrType_Stone', 'Neighborhood_NoRidge',
#      'WoodDeckSF', 'KitchenQual_Gd', 'BsmtExposure_No', '2ndFlrSF', 'OpenPorchSF',
#      'HeatingQC_TA', 'BsmtExposure_Gd', 'Exterior2nd_VinylSd', 'Exterior1st_VinylSd',
#      'MSZoning_RM', 'HalfBath', 'LotShape_Reg', 'LotArea', 'CentralAir_Y', 'MSZoning_RL',
#      'HouseStyle_2Story', 'SaleType_WD', 'Electrical_SBrkr', 'RoofStyle_Hip', 'GarageType_BuiltIn',
#      'BsmtQual_Gd', 'GarageType_Attchd', 'PavedDrive_Y', 'BsmtFullBath', 'RoofStyle_Gable',
#      'Neighborhood_StoneBr', 'BsmtUnfSF', 'MasVnrType_BrkFace', 'Neighborhood_OldTown',
#      'Neighborhood_NAmes', 'Neighborhood_Edwards', 'GarageFinish_RFn', 'RoofMatl_WdShngl',
#      'BedroomAbvGr', 'Exterior1st_MetalSd', 'Neighborhood_IDOTRR', 'Exterior2nd_MetalSd',
#      'Exterior2nd_Wd Sdng', 'Exterior1st_Wd Sdng', 'KitchenQual_Fa', 'SaleCondition_Normal',
#      'Neighborhood_BrkSide', 'LotConfig_CulDSac', 'Neighborhood_Somerst', 'ExterCond_Fa',
#      'GarageCond_TA', 'KitchenAbvGr', 'BsmtFinType1_Rec', 'HeatingQC_Gd', 'HeatingQC_Fa',
#      'Exterior1st_CemntBd', 'GarageQual_Fa', 'BsmtFinType1_Unf', 'BsmtFinType1_BLQ',
#      'GarageCond_Fa', 'BsmtQual_Fa', 'EnclosedPorch', 'Neighborhood_Sawyer', 'Exterior2nd_CmentBd',
#      'Electrical_FuseF', 'Neighborhood_Timber', 'LotShape_IR2', 'LandContour_HLS', 'Foundation_Slab',
#      'Condition1_Feedr', 'Functional_Typ', 'ExterQual_Fa', 'BldgType_Duplex', 'Condition1_Norm',
#      'Neighborhood_MeadowV', 'ScreenPorch', 'ExterCond_TA', 'RoofMatl_CompShg', 'Neighborhood_BrDale',
#      'BldgType_Twnhs', 'BldgType_2fmCon', 'GarageQual_TA', 'Exterior1st_HdBoard', 'HouseStyle_SFoyer',
#      'Heating_GasA', 'PoolArea', 'Heating_Grav', 'MSZoning_FV', 'BsmtCond_Gd', 'PavedDrive_P',
#      'HouseStyle_1.5Unf', 'BsmtFinType1_LwQ', 'MSSubClass', 'LotConfig_Inside', 'OverallCond',
#      'Exterior2nd_ImStucc', 'Neighborhood_CollgCr', 'Functional_Min2', 'Neighborhood_Crawfor',
#      'GarageType_CarPort', 'Functional_Maj2', 'Exterior2nd_HdBoard', 'MSZoning_RH', 'Functional_Min1',
#      'Neighborhood_SWISU', 'Neighborhood_Veenker', 'GarageCond_Po', 'HouseStyle_1Story', 'Heating_Wall',
#      'Neighborhood_Mitchel', 'BsmtFinType2_BLQ', 'BsmtFinType2_Unf', 'Neighborhood_ClearCr',
#      'BsmtCond_Po', 'Exterior2nd_Plywood', 'Exterior1st_WdShing', 'Exterior1st_BrkComm',
#      'SaleCondition_AdjLand', 'ExterCond_Gd', 'Condition1_PosN', 'Condition2_PosN', 'Condition2_Feedr',
#      'Electrical_FuseP', 'Condition2_PosA', 'Exterior2nd_Brk Cmn', 'Condition1_RRAe',
#      'SaleCondition_Family', 'MoSold', 'GarageQual_Po', 'LandContour_Low', 'Exterior2nd_Other',
#      'RoofMatl_WdShake', '3SsnPorch', 'BsmtExposure_Mn', 'GarageQual_Gd', 'LandSlope_Mod',
#      'Exterior2nd_Stucco', 'Condition1_PosA', 'SaleType_ConLD', 'SaleType_Con', 'Street_Pave',
#      'Exterior2nd_Wd Shng', 'BsmtFinType2_Rec', 'Condition2_RRNn', 'HouseStyle_SLvl',
#      'Neighborhood_NPkVill', 'BsmtFinType2_LwQ', 'Electrical_Mix', 'LotShape_IR3', 'HouseStyle_2.5Fin',
#      'Exterior1st_Stone', 'Neighborhood_Gilbert', 'RoofStyle_Gambrel', 'SaleType_Oth', 'ExterCond_Po',
#      'Exterior1st_BrkFace', 'HeatingQC_Po', 'Condition2_Norm', 'Exterior1st_Stucco', 'GarageType_Basment',
#      'YrSold', 'LandSlope_Sev', 'LandContour_Lvl', 'SaleType_ConLw', 'Exterior1st_ImStucc',
#      'Exterior1st_AsphShn', 'HouseStyle_2.5Unf', 'Heating_OthW', 'LowQualFinSF', 'Exterior2nd_CBlock',
#      'Exterior1st_CBlock', 'BsmtCond_TA', 'Exterior2nd_BrkFace', 'Exterior2nd_AsphShn',
#      'Neighborhood_NWAmes', 'Condition1_RRNn', 'MiscVal', 'RoofStyle_Shed', 'Neighborhood_Blueste',
#      'Heating_GasW', 'RoofMatl_Membran', 'SaleType_CWD', 'LotConfig_FR3', 'Exterior1st_Plywood',
#      'Functional_Sev', 'BsmtHalfBath', 'Exterior2nd_Stone', 'Functional_Mod', 'SaleCondition_Alloca',
#      'Neighborhood_SawyerW', 'Condition2_RRAn', 'RoofMatl_Roll', 'SaleType_ConLI', 'Utilities_NoSeWa',
#      'Foundation_Stone', 'BsmtFinSF2', 'LotConfig_FR2', 'Condition1_RRAn', 'RoofMatl_Tar&Grv',
#      'Condition1_RRNe', 'BldgType_TwnhsE', 'Condition2_RRAe', 'Foundation_Wood', 'GarageCond_Gd',
#      'RoofStyle_Mansard', 'RoofMatl_Metal', 'BsmtFinType2_GLQ']

# %%
# Feature params
fparams = \
    ['OverallQual', 'YearBuilt']

# Get params
train_target = train["SalePrice"].values
train_features = train[fparams].values
test_features  = test[fparams].values

# %% [markdown]
# Here's just use SVR for prediction, with GridSearch

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV, train_test_split

svrgs_parameters = {
    'kernel': ['rbf'],
    'C':     [150000,200000,250000],
    'gamma': [0.004,0.0045,0.005]
}

svr_cv = GridSearchCV(svm.SVR(), svrgs_parameters, cv=8, scoring= 'neg_mean_squared_log_error')
svr_cv.fit(train_features, train_target)
print("SVR GridSearch score: "+str(svr_cv.best_score_))
print("SVR GridSearch params: ")
print(svr_cv.best_params_)
# Out:
# SVR GridSearch score: -0.0514210457436
# SVR GridSearch params:
# {'C': 250000, 'gamma': 0.004, 'kernel': 'rbf'}

# %% [markdown]
# Output prediction result to a file

# %%
prediction = svr_cv.best_estimator_.predict(test_features)
pred = pd.DataFrame(pd.read_csv("./input/test.csv")['Id'])
pred['SalePrice'] = prediction
pred.to_csv("./input/submission_out.csv", index = False)
